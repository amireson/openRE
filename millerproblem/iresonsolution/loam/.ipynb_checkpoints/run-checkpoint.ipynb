# %%
# %load run.py
import numpy as np
import pandas as pd
import matplotlib.pyplot as pl

from Richards import run_RE

# %%
# Soil properties:
#import sys
#sys.path.insert(0,'..')
from setup import *

z=np.arange(dz,zN,dz)
n=len(z)

# Initial condition:
psi0=z-zN
# psi0[0]=0.1
dt=0.01

t=np.arange(0,tN+dt,dt)
nt=len(t)
BC_T=psiT+np.zeros(nt)
BC_B=psiB+np.zeros(nt)
dum,WB,runtime=run_RE(dt,t[:2],dz,zN,n,psi0,BC_T,BC_B,pars)
psi,WB,runtime=run_RE(dt,t,dz,zN,n,psi0,BC_T,BC_B,pars)
# Out:
# ode, with jac runtime = 0.08 seconds
# /Users/ani378/anaconda3/envs/python39/lib/python3.9/site-packages/scipy/integrate/_ode.py:1013: UserWarning: vode: Excess work done on this call. (Perhaps wrong MF.)
#   warnings.warn('{:s}: {:s}'.format(self.__class__.__name__,
# ode, with jac runtime = 32.40 seconds

# %%
dt
# Out:
# 0.01

# %%
pl.plot(psi[0,:],z)
pl.plot(psi[1,:],z)
pl.plot(psi[2,:],z)
pl.plot(psi[3,:],z)
pl.plot(psi[4,:],z)
pl.plot(psi[5,:],z)

# pl.ylim(0.1,0)
pl.ylim(0.25,0)
pl.grid()

# %%
dt=WB.index[1]-WB.index[0]
pl.subplot(1,2,1)
(WB['S']-WB['S'].iloc[0]).plot(marker='.')
((WB['QIN']-WB['QOUT'])*dt).cumsum().plot()
pl.subplot(1,2,2)
(WB['S'].diff()-((WB['QIN']-WB['QOUT']).iloc[:-1])*dt).plot(marker='.',linestyle='none')
# Out:
# <AxesSubplot:>

# %%
z=np.hstack([0,z,zN])
for i in range(nt):
    pl.plot(np.hstack([psiT,psi[i,:],psiB]),z)
    
pl.ylim(10,0)
pl.show()

psi=np.hstack([psiT,psi[-1,:],psiB])

# Save data:
fname='output/psi.csv'
f=open(fname,'w')
f.write('z, psi\n')


for i,j in zip (z,psi): f.write('%.4f, %.4f\n'%(i,j))
f.close()

f=open('output/runtime.csv','w')
f.write('%.3f\n'%runtime)
f.close()

fname='output/mb.csv'
WB.to_csv(fname,float_format='%12.8f')
